# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %matplotlib inline
# Out:
# /Users/moto/udemy/Streamlit_basic/venv/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# apple 株価情報取得 : ティッカーシンボル　　→ AAPL で引数してをして情報を取得
aapl = yf.Ticker('AAPL')

# %%
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
aapl.history()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-06-21  130.300003  132.410004  129.210007  132.300003   79663300
# 2021-06-22  132.130005  134.080002  131.619995  133.979996   74783600
# 2021-06-23  133.770004  134.320007  133.229996  133.699997   60214200
# 2021-06-24  134.449997  134.639999  132.929993  133.410004   68711000
# 2021-06-25  133.460007  133.889999  132.809998  133.110001   70783700
# 2021-06-28  133.410004  135.250000  133.350006  134.779999   62111300
# 2021-06-29  134.800003  136.490005  134.350006  136.330002   64556100
# 2021-06-30  136.169998  137.410004  135.869995  136.960007   63261400
# 2021-07-01  136.600006  137.330002  135.759995  137.270004   52485800
# 2021-07-02  137.899994  140.000000  137.750000  139.960007   78852600
# 2021-07-06  140.070007  143.149994  140.070007  142.020004  108181800
# 2021-07-07  143.539993  144.889999  142.660004  144.570007  104911600
# ...

# %%
# 21日分取得している
aapl.history().shape
# Out:
# (20, 7)

# %%
# 引数に　３０d = 30日分 data を取得してきてくれる
aapl.history(period='30d').shape
# Out:
# (30, 7)

# %%
days = 20
hist = aapl.history(period=f'{days}d')
hist
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-06-21  130.300003  132.410004  129.210007  132.300003   79663300
# 2021-06-22  132.130005  134.080002  131.619995  133.979996   74783600
# 2021-06-23  133.770004  134.320007  133.229996  133.699997   60214200
# 2021-06-24  134.449997  134.639999  132.929993  133.410004   68711000
# 2021-06-25  133.460007  133.889999  132.809998  133.110001   70783700
# 2021-06-28  133.410004  135.250000  133.350006  134.779999   62111300
# 2021-06-29  134.800003  136.490005  134.350006  136.330002   64556100
# 2021-06-30  136.169998  137.410004  135.869995  136.960007   63261400
# 2021-07-01  136.600006  137.330002  135.759995  137.270004   52485800
# 2021-07-02  137.899994  140.000000  137.750000  139.960007   78852600
# 2021-07-06  140.070007  143.149994  140.070007  142.020004  108181800
# 2021-07-07  143.539993  144.889999  142.660004  144.570007  104911600
# ...

# %%
# 上記は days が index の役割をしている
hist.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
# reset_index をすることで　0~ 連番でふられて、 data が column に移動する
hist.reset_index()
# Out:
#          Date        Open        High         Low       Close     Volume  \
# 0  2021-06-21  130.300003  132.410004  129.210007  132.300003   79663300
# 1  2021-06-22  132.130005  134.080002  131.619995  133.979996   74783600
# 2  2021-06-23  133.770004  134.320007  133.229996  133.699997   60214200
# 3  2021-06-24  134.449997  134.639999  132.929993  133.410004   68711000
# 4  2021-06-25  133.460007  133.889999  132.809998  133.110001   70783700
# 5  2021-06-28  133.410004  135.250000  133.350006  134.779999   62111300
# 6  2021-06-29  134.800003  136.490005  134.350006  136.330002   64556100
# 7  2021-06-30  136.169998  137.410004  135.869995  136.960007   63261400
# 8  2021-07-01  136.600006  137.330002  135.759995  137.270004   52485800
# 9  2021-07-02  137.899994  140.000000  137.750000  139.960007   78852600
# 10 2021-07-06  140.070007  143.149994  140.070007  142.020004  108181800
# 11 2021-07-07  143.539993  144.889999  142.660004  144.570007  104911600
# ...

# %%
# Micro soft
hist_msft = yf.Ticker('MSFT').history(period=f'{days}d')
hist_msft.head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-06-21  259.820007  263.519989  257.920013  262.630005  26696100
# 2021-06-22  262.720001  265.790009  262.399994  265.510010  24694100
# 2021-06-23  265.989990  266.829987  264.429993  265.269989  19518700
# 2021-06-24  266.160004  267.850006  265.470001  266.690002  21446900
# 2021-06-25  266.230011  267.250000  264.760010  265.019989  25611100
#
#             Dividends  Stock Splits
# Date
# 2021-06-21          0             0
# 2021-06-22          0             0
# 2021-06-23          0             0
# 2021-06-24          0             0
# 2021-06-25          0             0

# %%
# 対応する日付によって同じモノを横に並べて表示できる　（同じ index の物は並べて表示できる）
pd.concat([hist, hist_msft], axis=1).head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-06-21  130.300003  132.410004  129.210007  132.300003  79663300
# 2021-06-22  132.130005  134.080002  131.619995  133.979996  74783600
# 2021-06-23  133.770004  134.320007  133.229996  133.699997  60214200
# 2021-06-24  134.449997  134.639999  132.929993  133.410004  68711000
# 2021-06-25  133.460007  133.889999  132.809998  133.110001  70783700
#
#             Dividends  Stock Splits        Open        High         Low  \
# Date
# 2021-06-21          0             0  259.820007  263.519989  257.920013
# 2021-06-22          0             0  262.720001  265.790009  262.399994
# 2021-06-23          0             0  265.989990  266.829987  264.429993
# 2021-06-24          0             0  266.160004  267.850006  265.470001
# 2021-06-25          0             0  266.230011  267.250000  264.760010
#
#                  Close    Volume  Dividends  Stock Splits
# Date
# ...

# %%
hist.head(3)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-06-21  130.300003  132.410004  129.210007  132.300003  79663300
# 2021-06-22  132.130005  134.080002  131.619995  133.979996  74783600
# 2021-06-23  133.770004  134.320007  133.229996  133.699997  60214200
#
#             Dividends  Stock Splits
# Date
# 2021-06-21          0             0
# 2021-06-22          0             0
# 2021-06-23          0             0

# %%
hist.index
# Out:
# DatetimeIndex(['2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24',
#                '2021-06-25', '2021-06-28', '2021-06-29', '2021-06-30',
#                '2021-07-01', '2021-07-02', '2021-07-06', '2021-07-07',
#                '2021-07-08', '2021-07-09', '2021-07-12', '2021-07-13',
#                '2021-07-14', '2021-07-15', '2021-07-16', '2021-07-19'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
hist.index = hist.index.strftime('%d %B %Y')

# %%
hist.head()
# Out:
#                     Open        High         Low       Close    Volume  \
# Date
# 21 June 2021  130.300003  132.410004  129.210007  132.300003  79663300
# 22 June 2021  132.130005  134.080002  131.619995  133.979996  74783600
# 23 June 2021  133.770004  134.320007  133.229996  133.699997  60214200
# 24 June 2021  134.449997  134.639999  132.929993  133.410004  68711000
# 25 June 2021  133.460007  133.889999  132.809998  133.110001  70783700
#
#               Dividends  Stock Splits
# Date
# 21 June 2021          0             0
# 22 June 2021          0             0
# 23 June 2021          0             0
# 24 June 2021          0             0
# 25 June 2021          0             0

# %%
hist = hist[['Close']]
hist.columns = ['apple']

# %%
hist.head()
# Out:
#                    apple
# Date
# 21 June 2021  132.300003
# 22 June 2021  133.979996
# 23 June 2021  133.699997
# 24 June 2021  133.410004
# 25 June 2021  133.110001

# %%
# 列と行を入れ替える
hist = hist.T

# %%
hist.index.name = 'Name'

# %%
hist
# Out:
# Date   21 June 2021  22 June 2021  23 June 2021  24 June 2021  25 June 2021  \
# Name
# apple    132.300003    133.979996    133.699997    133.410004    133.110001
#
# Date   28 June 2021  29 June 2021  30 June 2021  01 July 2021  02 July 2021  \
# Name
# apple    134.779999    136.330002    136.960007    137.270004    139.960007
#
# Date   06 July 2021  07 July 2021  08 July 2021  09 July 2021  12 July 2021  \
# Name
# apple    142.020004    144.570007    143.240005    145.110001         144.5
#
# Date   13 July 2021  14 July 2021  15 July 2021  16 July 2021  19 July 2021
# Name
# apple    145.639999    149.149994    148.479996    146.389999    142.949997

# %%
# 関数で一まとめにする
def get_data(days, tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
    # company = 'facebook'
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d')
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netfilx': 'NFLX',
    'amazon': 'AMZN'
}
get_data(days, tickers)
# Out:
# Date       21 June 2021  22 June 2021  23 June 2021  24 June 2021  \
# Name
# apple        132.300003    133.979996    133.699997    133.410004
# facebook     332.290009    339.029999    340.589996    343.179993
# google      2436.250000   2446.610107   2442.540039   2450.000000
# microsoft    262.630005    265.510010    265.269989    266.690002
# netfilx      497.000000    508.820007    512.739990    518.059998
# amazon      3453.959961   3505.439941   3503.820068   3449.080078
#
# Date       25 June 2021  28 June 2021  29 June 2021  30 June 2021  \
# Name
# apple        133.110001    134.779999    136.330002    136.960007
# facebook     341.369995    355.640015    351.890015    347.709991
# google      2450.169922   2450.719971   2445.449951   2441.790039
# microsoft    265.019989    268.720001    271.399994    270.899994
# netfilx      527.070007    533.030029    533.500000    528.210022
# amazon      3401.459961   3443.889893   3448.139893   3440.159912
#
# ...

# %% [markdown]
# ## 会社情報や株の配当金分割なども取得できる

# %%
pip install altair
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt

# %%
df
# Out:
# Date       21 June 2021  22 June 2021  23 June 2021  24 June 2021  \
# Name
# apple        132.300003    133.979996    133.699997    133.410004
# facebook     332.290009    339.029999    340.589996    343.179993
# google      2436.250000   2446.610107   2442.540039   2450.000000
# microsoft    262.630005    265.510010    265.269989    266.690002
# netfilx      497.000000    508.820007    512.739990    518.059998
# amazon      3453.959961   3505.439941   3503.820068   3449.080078
#
# Date       25 June 2021  28 June 2021  29 June 2021  30 June 2021  \
# Name
# apple        133.110001    134.779999    136.330002    136.960007
# facebook     341.369995    355.640015    351.890015    347.709991
# google      2450.169922   2450.719971   2445.449951   2441.790039
# microsoft    265.019989    268.720001    271.399994    270.899994
# netfilx      527.070007    533.030029    533.500000    528.210022
# amazon      3401.459961   3443.889893   3448.139893   3440.159912
#
# ...

# %%
companies = ['apple', 'facebook']
data = df.loc[companies]
data
# Out:
# Date      21 June 2021  22 June 2021  23 June 2021  24 June 2021  \
# Name
# apple       132.300003    133.979996    133.699997    133.410004
# facebook    332.290009    339.029999    340.589996    343.179993
#
# Date      25 June 2021  28 June 2021  29 June 2021  30 June 2021  \
# Name
# apple       133.110001    134.779999    136.330002    136.960007
# facebook    341.369995    355.640015    351.890015    347.709991
#
# Date      01 July 2021  02 July 2021  06 July 2021  07 July 2021  \
# Name
# apple       137.270004    139.960007    142.020004    144.570007
# facebook    354.390015    354.700012    352.779999    350.489990
#
# Date      08 July 2021  09 July 2021  12 July 2021  13 July 2021  \
# Name
# apple       143.240005    145.110001    144.500000    145.639999
# facebook    345.649994    350.420013    353.160004    352.089996
#
# Date      14 July 2021  15 July 2021  16 July 2021  19 July 2021
# Name
# apple       149.149994    148.479996    146.389999    141.970001
# ...

# %%
# abc順に変えてくれる
data.sort_index()
# Out:
# Date      21 June 2021  22 June 2021  23 June 2021  24 June 2021  \
# Name
# apple       132.300003    133.979996    133.699997    133.410004
# facebook    332.290009    339.029999    340.589996    343.179993
#
# Date      25 June 2021  28 June 2021  29 June 2021  30 June 2021  \
# Name
# apple       133.110001    134.779999    136.330002    136.960007
# facebook    341.369995    355.640015    351.890015    347.709991
#
# Date      01 July 2021  02 July 2021  06 July 2021  07 July 2021  \
# Name
# apple       137.270004    139.960007    142.020004    144.570007
# facebook    354.390015    354.700012    352.779999    350.489990
#
# Date      08 July 2021  09 July 2021  12 July 2021  13 July 2021  \
# Name
# apple       143.240005    145.110001    144.500000    145.639999
# facebook    345.649994    350.420013    353.160004    352.089996
#
# Date      14 July 2021  15 July 2021  16 July 2021  19 July 2021
# Name
# apple       149.149994    148.479996    146.389999    141.970001
# ...

# %%
# 行と列を入れ替え
data = data.T.reset_index()
data.head()
# Out:
# Name          Date       apple    facebook
# 0     21 June 2021  132.300003  332.290009
# 1     22 June 2021  133.979996  339.029999
# 2     23 June 2021  133.699997  340.589996
# 3     24 June 2021  133.410004  343.179993
# 4     25 June 2021  133.110001  341.369995

# %%
# メルト関数　: ピポットテーブル　(の逆を行なっている) -> 整形してある data frame をあえて Date 基準で崩した形
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices(USD)'}
)
data
# Out:
#             Date      Name  Stock Prices(USD)
# 0   21 June 2021     apple         132.300003
# 1   22 June 2021     apple         133.979996
# 2   23 June 2021     apple         133.699997
# 3   24 June 2021     apple         133.410004
# 4   25 June 2021     apple         133.110001
# 5   28 June 2021     apple         134.779999
# 6   29 June 2021     apple         136.330002
# 7   30 June 2021     apple         136.960007
# 8   01 July 2021     apple         137.270004
# 9   02 July 2021     apple         139.960007
# 10  06 July 2021     apple         142.020004
# 11  07 July 2021     apple         144.570007
# 12  08 July 2021     apple         143.240005
# 13  09 July 2021     apple         145.110001
# 14  12 July 2021     apple         144.500000
# 15  13 July 2021     apple         145.639999
# 16  14 July 2021     apple         149.149994
# 17  15 July 2021     apple         148.479996
# 18  16 July 2021     apple         146.389999
# ...

# %%
ymin, ymax = 100, 400

chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y('Stock Prices(USD):Q', stack=None, scale=alt.Scale(domain=[ymin,ymax])),
        color='Name:N'        
    )
)

# %%
chart
# Out:
# alt.Chart(...)

# %%
appl = yf.Ticker('AAPL')

# %%
# 会社情報
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
# 配当金と株式分割の情報
aapl.actions.head()
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
aapl.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
aapl.actions['Stock Splits'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
